# %% [markdown]
# # Occupancy Detection in Spinlab with AirQ Data
#
# ### A multivariate time series example
#
# In this tutorial, you will learn how to apply getML to multivariate time series. It also demonstrates how to use getML's hyperparameter tuning routines.
#
# Summary:
#
# - Prediction type: __Binary classification__
# - Domain: __Energy__
# - Prediction target: __Room occupancy__
# - Source data: __2 tables, 37k rows__
# - Population size: __29k__
#
# _Author: Julian Oestreich_

# %% [markdown]
# The goal of this work is straight forward. Based on sensordata we want to predict wether is room vacant or not.
#
# This notebook shall also show the effect of additional data on our analysis.
#
# We're using two datasets to analyse the occupancy of rooms with sensordata:
# - Dataset collected with a Raspberry Pi in the entrance area of Spinlab:
#     - **Variables**:
#         * Date, year-month-day hour:minute:second
#         * Temperature, in Celsius
#         * Relative Humidity, %
#         * Light, in Lux
#         * Motion_Count, Integer
#         * Occupancy, 0 or 1, 0 for not occupied, 1 for occupied status
#     - **Size**: 29290 Rows
#     - **Resolution**: ~1min
# - Dataset created by combining the CSV Exports of the AirQ Webinterface Diagrams:
#     - **Variables**:
#         * Sound, in db
#         * CO2, in ppm
#     - **Size**: 8198 Rows
#     - **Resolution**: ~4min

# %%
import os
import datetime
import numpy as np
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline  

import getml

print(f"getML API version: {getml.__version__}\n")

getml.engine.set_project('occupancy_airq')
# Out:
# getML API version: 0.13.0
#
# Loading existing project 'occupancy_airq'

# %% [markdown]
# # 1. Memory Tracker

# %%
import threading
import psutil
import time

# %%
class MemoryTracker():
    """
    The MemoryTracker measures the system's memory consumption
    once every second. It can be used to get an approximation of 
    the overall memory consumption of certain algorithms.
    """
    
    def __init__(self):
        self._initial_usage = 0
        self._max_usage = 0
        
        self._stop = False
        
        self.lock = threading.Lock()
        
        self.th = threading.Thread(
            target=self._measure_memory_usage,
        )
        
    def __del__(self):
        self.stop()
        
    def _get_memory_usage(self):
        return psutil.virtual_memory().used

    def _measure_memory_usage(self):
        while True:
            time.sleep(1)
            
            self.lock.acquire()
                                    
            if self._stop:
                self.lock.release()
                break
            
            current_usage = self._get_memory_usage()
            
            if current_usage > self._max_usage:
                self._max_usage = current_usage
            
            self.lock.release()

    @property
    def peak_consumption(self):
        """
        The peak system memory consumption, in GB
        """
        self.lock.acquire()
        
        p_con = self._max_usage - self._initial_usage
        
        self.lock.release()
        
        p_con /= 1e9
        
        return p_con
    
    def start(self):
        """
        Starts measuring the memory consumption.
        """
        self.lock.acquire()
        
        self._initial_usage = self._get_memory_usage()
        
        self._max_usage = self._initial_usage
        
        self._stop = False
        
        self.th = threading.Thread(
            target=self._measure_memory_usage,
        )
        
        self.th.start()
        
        self.lock.release()
        
    def stop(self):
        """
        Stops measuring the memory consumption.
        """
        self.lock.acquire()
        self._stop = True
        self.lock.release()

# %%
memory_tracker = MemoryTracker()

# %% [markdown]
# # 2. Data Preparation and Visualization

# %%
airq_data = pd.read_csv('combined.csv', sep=';')
spinlab_data = pd.read_csv('spinlab_19.11.20.csv')

# %%
spinlab_data["date"] = pd.to_datetime(spinlab_data["created_time"])
spinlab_data.occupancy.replace(('f', 't'), (0, 1), inplace=True)
spinlab_data.drop('people_count', 1, inplace=True)
spinlab_data.drop('id', 1, inplace=True)
spinlab_data.drop('created_time', 1, inplace=True)
spinlab_data.dropna(inplace=True)
spinlab_data
# Out:
#        temperature   humidity      light  occupancy  \
# 0        21.299999  49.200001   0.000000          0
# 1        21.299999  49.700001  14.166667          0
# 2        21.299999  49.799999  14.166667          0
# 3        21.299999  49.799999  14.166667          0
# 4        21.299999  49.799999  14.166667          0
# ...            ...        ...        ...        ...
# 29285    21.400000  46.500000   1.666667          0
# 29286    21.400000  46.500000   1.666667          0
# 29287    21.299999  46.500000   1.666667          0
# 29288    21.400000  46.599998   1.666667          0
# 29289    21.400000  46.500000   1.666667          0
#
#                                   date
# 0     2020-10-28 17:17:02.752521+00:00
# 1     2020-10-28 17:18:32.387812+00:00
# 2     2020-10-28 17:19:32.983309+00:00
# 3     2020-10-28 17:20:33.578042+00:00
# 4     2020-10-28 17:21:34.173782+00:00
# ...                                ...
# 29285 2020-11-18 06:29:43.843737+00:00
# 29286 2020-11-18 06:30:44.438517+00:00
# 29287 2020-11-18 06:31:45.033210+00:00
# 29288 2020-11-18 06:32:45.628052+00:00
# 29289 2020-11-18 06:33:48.749100+00:00
#
# [29290 rows x 5 columns]

# %%
airq_data['sound'] = airq_data['sound'].str.replace(',','.').astype(float)
airq_data['co2'] = airq_data['co2'].str.replace(',','.').astype(float)
airq_data["date"] = pd.to_datetime(airq_data["date"])

# %%
airq_data
# Out:
#                     date    sound       co2
# 0    2020-10-27 23:04:01  38.6815  466.4755
# 1    2020-10-27 23:08:02  38.5130  463.3480
# 2    2020-10-27 23:12:04  38.5720  464.1220
# 3    2020-10-27 23:16:05  38.4320  465.1120
# 4    2020-10-27 23:20:08  38.5365  465.8085
# ...                  ...      ...       ...
# 8193 2020-11-19 22:41:21  38.2840  518.4935
# 8194 2020-11-19 22:45:22  38.1280  517.8640
# 8195 2020-11-19 22:49:24  38.2845  514.4445
# 8196 2020-11-19 22:53:26  38.5625  516.1480
# 8197 2020-11-19 22:57:27  38.4205  513.2600
#
# [8198 rows x 3 columns]

# %%
airq_data['sound']
# Out:
# 0       38.6815
# 1       38.5130
# 2       38.5720
# 3       38.4320
# 4       38.5365
#          ...
# 8193    38.2840
# 8194    38.1280
# 8195    38.2845
# 8196    38.5625
# 8197    38.4205
# Name: sound, Length: 8198, dtype: float64

# %%
start_date = '2020-11-01'
end_date = '2020-11-04'

airq_mask = (airq_data['date'] > start_date) & (airq_data['date'] <= end_date)
airq_slice = airq_data.loc[airq_mask]

spinlab_mask = (spinlab_data['date'] > start_date) & (spinlab_data['date'] <= end_date)
spinlab_slice = spinlab_data.loc[spinlab_mask]

# %%
airq_slice
# Out:
#                     date    sound       co2
# 1442 2020-11-01 00:03:26  38.8710  487.8170
# 1443 2020-11-01 00:07:27  39.0205  485.3335
# 1444 2020-11-01 00:11:28  38.9305  486.2160
# 1445 2020-11-01 00:15:30  39.0020  487.3435
# 1446 2020-11-01 00:19:30  38.8770  486.7795
# ...                  ...      ...       ...
# 2507 2020-11-03 23:42:28  38.4140  542.9875
# 2508 2020-11-03 23:46:29  38.3625  542.8790
# 2509 2020-11-03 23:50:30  38.4395  542.5190
# 2510 2020-11-03 23:54:32  38.4870  544.5235
# 2511 2020-11-03 23:58:33  38.6730  542.9630
#
# [1070 rows x 3 columns]

# %%
spinlab_slice['temperature']
# Out:
# 4666    21.000000
# 4667    21.000000
# 4668    21.000000
# 4669    21.000000
# 4670    21.000000
#           ...
# 8937    21.200001
# 8938    21.200001
# 8939    21.200001
# 8940    21.200001
# 8941    21.200001
# Name: temperature, Length: 4276, dtype: float64

# %%
max(spinlab_slice['date'].values)
# Out:
# numpy.datetime64('2020-11-03T23:59:33.409226000')

# %%
for i, col in enumerate(spinlab_data.columns.values[:-1]):
    plt.subplot(6, 1, i+1) 
    plt.plot(spinlab_slice['date'].values, spinlab_slice[col].values.tolist(), label=col, color='#6829c2')
    plt.axvline('2020-11-03T00:00:00.000000000', color='grey', linestyle='--')
    plt.axvline('2020-11-04T00:00:00.000000000', color='grey', linestyle='--')
    plt.title(col)

for i, col in enumerate(airq_data.columns.values[1:]):
    i = i + 4
    plt.subplot(6, 1, i+1)
    plt.plot(airq_slice['date'].values, airq_slice[col].values.tolist(), label=col, color='#6829c2')
    plt.axvline('2020-11-03T00:00:00.000000000', color='grey', linestyle='--')
    plt.axvline('2020-11-04T00:00:00.000000000', color='grey', linestyle='--')
    plt.title(col)
    
fig, ax = plt.gcf(), plt.gca()
ax.xaxis_date()
fig.autofmt_xdate()
fig.set_size_inches(20, 10)
plt.grid(True)
plt.show()

# %%
def dt_to_isoformat(x):
    timestring = x.isoformat()
    return timestring.split('+')[0]

# %%
spinlab_data['date'] = spinlab_data['date'].apply(dt_to_isoformat)

# %% [markdown]
# # 3. With AirQ Data
# ## 3.1 Automated Feature Engineering with GetML

# %%
train = spinlab_data[:int(len(spinlab_data)*0.7)]
test = spinlab_data[int(len(spinlab_data)*0.7):]

# %%
air_q = getml.data.DataFrame.from_pandas(airq_data, "air_q")
test = getml.data.DataFrame.from_pandas(test, "test")
train = getml.data.DataFrame.from_pandas(train, "train")

# %%
train
# Out:
# Name     temperature       humidity          light
# Role    unused_float   unused_float   unused_float
# 0       21.3           49.2           0
# 1       21.3           49.7           14.1667
# 2       21.3           49.8           14.1667
# 3       21.3           49.8           14.1667
# 4       21.3           49.8           14.1667
#         ...            ...            ...
# 20498   21.1           43.7           1.66667
# 20499   21.1           43.7           1.66667
# 20500   21.1           43.7           1.66667
# 20501   21             43.6           1.66667
# 20502   21.1           43.7           1.66667
#
#
#
# Name       occupancy                         date
# Role    unused_float                unused_string
# 0       0              2020-10-28T17:17:02.752521
# 1       0              2020-10-28T17:18:32.387812
# 2       0              2020-10-28T17:19:32.983309
# 3       0              2020-10-28T17:20:33.578042
# 4       0              2020-10-28T17:21:34.173782
#         ...            ...
# 20498   0              2020-11-12T02:34:11.292340
# 20499   0              2020-11-12T02:35:11.843801
# 20500   0              2020-11-12T02:36:12.411774
# 20501   0              2020-11-12T02:37:13.006317
# 20502   0              2020-11-12T02:38:13.601197
#
# 20503 rows x 5 columns
# memory usage: 1.37 MB
# name: train
# type: getml.data.DataFrame
# url: http://localhost:1709/getdataframe/train/

# %%
for df in [train, test]:
    df.set_role("occupancy", getml.data.roles.target)
    df.set_role(['temperature', 'humidity', 'light'], getml.data.roles.numerical)
    df.set_role("date", getml.data.roles.time_stamp, time_formats=['%Y-%m-%dT%H:%M:%S.%F'])

# %%
train
# Out:
# Name                           date   occupancy   temperature
# Role                     time_stamp      target     numerical
# Unit    time stamp, comparison only
# 0       2020-10-28T17:17:02.752521Z   0           21.3
# 1       2020-10-28T17:18:32.387812Z   0           21.3
# 2       2020-10-28T17:19:32.983309Z   0           21.3
# 3       2020-10-28T17:20:33.578042Z   0           21.3
# 4       2020-10-28T17:21:34.173782Z   0           21.3
#         ...                           ...         ...
# 20498   2020-11-12T02:34:11.292340Z   0           21.1
# 20499   2020-11-12T02:35:11.843801Z   0           21.1
# 20500   2020-11-12T02:36:12.411774Z   0           21.1
# 20501   2020-11-12T02:37:13.006317Z   0           21
# 20502   2020-11-12T02:38:13.601197Z   0           21.1
#
#
#
# Name     humidity       light
# Role    numerical   numerical
# Unit
# 0       49.2        0
# 1       49.7        14.1667
# 2       49.8        14.1667
# 3       49.8        14.1667
# 4       49.8        14.1667
#         ...         ...
# 20498   43.7        1.66667
# 20499   43.7        1.66667
# 20500   43.7        1.66667
# 20501   43.6        1.66667
# 20502   43.7        1.66667
#
# 20503 rows x 5 columns
# memory usage: 0.82 MB
# name: train
# type: getml.data.DataFrame
# url: http://localhost:1709/getdataframe/train/

# %%
air_q.set_role(['co2', 'sound'], getml.data.roles.numerical)
air_q.set_role("date", getml.data.roles.time_stamp, time_formats=['%Y-%m-%dT%H:%M:%S.%F'])

# %%
air_q
# Out:
# Name                          date         co2       sound
# Role                    time_stamp   numerical   numerical
# Unit   time stamp, comparison only
# 0      2020-10-27T23:04:01.000000Z   466.476     38.6815
# 1      2020-10-27T23:08:02.000000Z   463.348     38.513
# 2      2020-10-27T23:12:04.000000Z   464.122     38.572
# 3      2020-10-27T23:16:05.000000Z   465.112     38.432
# 4      2020-10-27T23:20:08.000000Z   465.808     38.5365
#        ...                           ...         ...
# 8193   2020-11-19T22:41:21.000000Z   518.494     38.284
# 8194   2020-11-19T22:45:22.000000Z   517.864     38.128
# 8195   2020-11-19T22:49:24.000000Z   514.444     38.2845
# 8196   2020-11-19T22:53:26.000000Z   516.148     38.5625
# 8197   2020-11-19T22:57:27.000000Z   513.26      38.4205
#
# 8198 rows x 3 columns
# memory usage: 0.2 MB
# name: air_q
# type: getml.data.DataFrame
# url: http://localhost:1709/getdataframe/air_q/

# %%
population = getml.data.Placeholder('population')

spinlab = getml.data.Placeholder('spinlab')

airq = getml.data.Placeholder('airq')

# 1. The horizon is 0 (we do not predict future data). 
# 2. The memory is 30 mins, so we allow the algorithm to 
#    use information from up to 30 minutes ago. 

population.join(
    spinlab,
    time_stamp='date',
    horizon=getml.data.time.hours(0),
    memory=getml.data.time.minutes(30)
)

population.join(
    airq,
    time_stamp='date',
    horizon=getml.data.time.hours(0),
    memory=getml.data.time.minutes(30)
)

population
# Out:
# placeholder   other placeholder   allow lagged targets   horizon
# population    spinlab             False                  0.0
# population    airq                False                  0.0
#
#
#
# join keys used   memory   other join keys used   other time stamps used
#                  1800.0                          date
#                  1800.0                          date
#
#
#
# join keys used   relationship   time stamps used   ...
#                  many-to-many   date               ...
#                  many-to-many   date               ...

# %%
multirel = getml.feature_learning.MultirelModel(
    num_features=10,
    loss_function=getml.feature_learning.loss_functions.CrossEntropyLoss,
    seed=4367,
    num_threads=6
)

relboost = getml.feature_learning.RelboostModel(
    num_features=10,
    loss_function=getml.feature_learning.loss_functions.CrossEntropyLoss,
    seed=4367,
    num_threads=6
)

predictor = getml.predictors.LogisticRegression()

# %%
pipe_airq = getml.pipeline.Pipeline(
    tags=['memory: 30m', 'horizon: 0m', 'multirel', 'relboost'],
    population=population,
    peripheral=[spinlab, airq],
    feature_learners=[multirel, relboost],
    predictors=[predictor]
)

# %%
pipe_airq.fit(train, [train, air_q])
# Out:
# Checking data model...
# OK.
#
# Multirel: Training features...
# [========================================] 100%
#
# Relboost: Training features...
# [========================================] 100%
#
# Multirel: Building features...
# [========================================] 100%
#
# Relboost: Building features...
# [========================================] 100%
#
# LogisticRegression: Training as predictor...
# [========================================] 100%
#
# Trained pipeline.
# Time taken: 0h:1m:29.415982
# Pipeline(preprocessors=[], feature_learners=['MultirelModel', 'RelboostModel'],
#          feature_selectors=[], include_categorical=False,
#          peripheral=['spinlab', 'airq'], population='population',
#          predictors=['LogisticRegression'],
#          tags=['memory: 30m', 'horizon: 0m', 'multirel', 'relboost'],
#          share_selected_features=0.5)
#
# url: http://localhost:1709/getpipeline/vpjcPf/0/

# %%
in_sample = pipe_airq.score(
        population_table=train,
        peripheral_tables=[train, air_q]
)

out_of_sample = pipe_airq.score(
        population_table=test,
        peripheral_tables=[test, air_q]
)
# Out:
# Multirel: Building features...
# [========================================] 100%
#
# Relboost: Building features...
# [========================================] 100%
#
#
# Multirel: Building features...
# [========================================] 100%
#
# Relboost: Building features...
# [========================================] 100%

# %%
in_sample
# Out:
# {'accuracy': [0.8532897624737843],
#  'auc': [0.8934570408167535],
#  'cross_entropy': [0.37560489402494845]}

# %%
out_of_sample
# Out:
# {'accuracy': [0.8462501422556049],
#  'auc': [0.8503149594424617],
#  'cross_entropy': [0.39512318390827045]}

# %%
# Refers to the data from the last time
# we called .score(...).
fpr, tpr = pipe_airq.metrics.roc_curve()

plt.subplots(figsize=(20, 10))
print(fpr[0])
plt.plot(fpr, tpr, color='#6829c2')
plt.plot([0.0, 0.0], [1.0, 1.0], ls="-", color='black')
plt.title("receiver operating characteristic (ROC)")
plt.grid(True)
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")

plt.show()
# Out:
# 1.0

# %%
names, correlations = pipe_airq.features.correlations()

plt.subplots(figsize=(20, 10))

plt.bar(names, correlations, color='#6829c2')
plt.title("feature correlations")
plt.grid(True)
plt.xlabel("features")
plt.ylabel("correlations")
plt.xticks(rotation='vertical')

plt.show()

# %%
names, importances = pipe_airq.features.importances()

plt.subplots(figsize=(20, 10))

plt.bar(names, importances, color='#6829c2')

plt.title("feature importances")
plt.grid(True)
plt.xlabel("features")
plt.ylabel("importance")
plt.xticks(rotation='vertical')

plt.show()

# %%
pipe_airq.features.to_sql()[names[1]]
# Out:
# DROP TABLE IF EXISTS "FEATURE_2_7";
#
# CREATE TABLE "FEATURE_2_7" AS
# SELECT SUM(
#     CASE
#         WHEN ( t2."light" > 14.045699 ) AND ( t1."light" > 13.149718 ) AND ( julianday( t1."date" ) > julianday( t2."date", '+1.278586 minutes' ) ) THEN -0.01890790711949302
#         WHEN ( t2."light" > 14.045699 ) AND ( t1."light" > 13.149718 ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+1.278586 minutes' ) OR julianday( t1."date" ) IS NULL OR julianday( t2."date", '+1.278586 minutes' ) IS NULL ) THEN 0.8795367666496701
#         WHEN ( t2."light" > 14.045699 ) AND ( t1."light" <= 13.149718 OR t1."light" IS NULL ) AND ( t2."light" > 68.399471 ) THEN 0.0434585376811099
#         WHEN ( t2."light" > 14.045699 ) AND ( t1."light" <= 13.149718 OR t1."light" IS NULL ) AND ( t2."light" <= 68.399471 OR t2."light" IS NULL ) THEN 0.1275982405305102
#         WHEN ( t2."light" <= 14.045699 OR t2."light" IS NULL ) AND ( t2."humidity" > 44.071120 ) AND ( t2."light" > 1.655773 ) THEN -0.01407382315371551
#         WHEN ( t2."light" <= 14.045699 OR t2."light" IS NULL ) AND ( t2."humidity" > 44.071120 ) AND ( t2."light" <= 1.655773 OR t2."light" IS NULL ) THEN 0.3642152166461716
#         WHEN ( t2."light" <= 14.045699 OR t2."light" IS NULL ) AND ( t2."humidity" <= 44.071120 OR t2."humidity" IS NULL ) AND ( t2."humidity" > 43.693151 ) THEN 0.05029403184186957
#         WHEN ( t2."light" <= 14.045699 OR t2."light" IS NULL ) AND ( t2."humidity" <= 44.071120 OR t2."humidity" IS NULL ) AND ( t2."humidity" <= 43.693151 OR t2."humidity" IS NULL ) THEN -0.001944921919292185
#         ELSE NULL
#     END
# ) AS "feature_2_7",
#      t1.rowid AS "rownum"
# FROM "population" t1
# LEFT JOIN "spinlab" t2
# ON 1 = 1
# WHERE julianday( t2."date" ) <= julianday( t1."date" )
# AND ( julianday( t2."date", '+30.000000 minutes' ) > julianday( t1."date" ) OR julianday( t2."date", '+30.000000 minutes' ) IS NULL )
# GROUP BY t1.rowid;

# %%
pipe_airq.features.to_sql()[names[2]]
# Out:
# DROP TABLE IF EXISTS "FEATURE_1_5";
#
# CREATE TABLE "FEATURE_1_5" AS
# SELECT MAX( t2."sound" ) AS "feature_1_5",
#        t1.rowid AS "rownum"
# FROM "population" t1
# LEFT JOIN "airq" t2
# ON 1 = 1
# WHERE ( julianday( t2."date" ) <= julianday( t1."date" )
# AND ( julianday( t2."date", '+30.000000 minutes' ) > julianday( t1."date" ) OR julianday( t2."date", '+30.000000 minutes' ) IS NULL )
# ) AND (
#    ( ( t2."sound" > 44.810784 ) AND ( julianday( t1."date" ) > julianday( t2."date", '+15.520828 minutes' ) ) AND ( t1."humidity" > 46.299999 ) AND ( t1."light" <= 64.772727 ) )
# OR ( ( t2."sound" > 44.810784 ) AND ( julianday( t1."date" ) > julianday( t2."date", '+15.520828 minutes' ) ) AND ( t1."humidity" <= 46.299999 OR t1."humidity" IS NULL  ) AND ( t1."humidity" <= 38.736364 ) )
# OR ( ( t2."sound" > 44.810784 ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+15.520828 minutes' ) ) AND ( t2."sound" > 71.425048 OR t2."sound" IS NULL  ) AND ( t1."temperature" > 21.766666 ) )
# OR ( ( t2."sound" > 44.810784 ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+15.520828 minutes' ) ) AND ( t2."sound" <= 71.425048 ) )
# OR ( ( t2."sound" <= 44.810784 OR t2."sound" IS NULL  ) AND ( t2."co2" > 446.284136 OR t2."co2" IS NULL  ) AND ( t2."sound" > 38.474920 OR t2."sound" IS NULL  ) AND ( t1."light" > 40.833333 ) )
# OR ( ( t2."sound" <= 44.810784 OR t2."sound" IS NULL  ) AND ( t2."co2" > 446.284136 OR t2."co2" IS NULL  ) AND ( t2."sound" <= 38.474920 ) AND ( t2."co2" <= 547.893267 ) )
# OR ( ( t2."sound" <= 44.810784 OR t2."sound" IS NULL  ) AND ( t2."co2" <= 446.284136 ) AND ( t2."co2" > 442.785652 ) AND ( t1."humidity" <= 50.936365 ) )
# OR ( ( t2."sound" <= 44.810784 OR t2."sound" IS NULL  ) AND ( t2."co2" <= 446.284136 ) AND ( t2."co2" <= 442.785652 OR t2."co2" IS NULL  ) AND ( t2."sound" <= 40.764075 ) )
# )
# GROUP BY t1.rowid;

# %%
pipe_airq.columns.to_pandas()
# Out:
#    population/peripheral       table         name  importance     target
# 0           [PERIPHERAL]        airq          co2    0.025774  occupancy
# 1           [PERIPHERAL]        airq         date    0.012585  occupancy
# 2           [PERIPHERAL]        airq        sound    0.334523  occupancy
# 3           [PERIPHERAL]     spinlab         date    0.004185  occupancy
# 4           [PERIPHERAL]     spinlab     humidity    0.009038  occupancy
# 5           [PERIPHERAL]     spinlab        light    0.155797  occupancy
# 6           [PERIPHERAL]     spinlab  temperature    0.000217  occupancy
# 7           [POPULATION]  population         date    0.016770  occupancy
# 8           [POPULATION]  population     humidity    0.032922  occupancy
# 9           [POPULATION]  population        light    0.380894  occupancy
# 10          [POPULATION]  population  temperature    0.027293  occupancy

# %%
names, importances = pipe_airq.columns.importances()

names = [name.split('.')[1] for name in names]

plt.subplots(figsize=(20, 10))

plt.bar(names, importances, color='#6829c2')

plt.title("column importances")
plt.grid(True)
plt.xlabel("columns")
plt.ylabel("importance")
plt.xticks(rotation='horizontal')

plt.show()

# %% [markdown]
# ## 3.2 Automated Feature Engineering with Featuretools

# %% [markdown]
# ### 3.2.1 Set Index Column

# %%
spinlab_data = spinlab_data.reset_index()
spinlab_data
# Out:
#        index  temperature   humidity      light  occupancy  \
# 0          0    21.299999  49.200001   0.000000          0
# 1          1    21.299999  49.700001  14.166667          0
# 2          2    21.299999  49.799999  14.166667          0
# 3          3    21.299999  49.799999  14.166667          0
# 4          4    21.299999  49.799999  14.166667          0
# ...      ...          ...        ...        ...        ...
# 29285  29285    21.400000  46.500000   1.666667          0
# 29286  29286    21.400000  46.500000   1.666667          0
# 29287  29287    21.299999  46.500000   1.666667          0
# 29288  29288    21.400000  46.599998   1.666667          0
# 29289  29289    21.400000  46.500000   1.666667          0
#
#                              date
# 0      2020-10-28T17:17:02.752521
# 1      2020-10-28T17:18:32.387812
# 2      2020-10-28T17:19:32.983309
# 3      2020-10-28T17:20:33.578042
# 4      2020-10-28T17:21:34.173782
# ...                           ...
# 29285  2020-11-18T06:29:43.843737
# 29286  2020-11-18T06:30:44.438517
# 29287  2020-11-18T06:31:45.033210
# 29288  2020-11-18T06:32:45.628052
# 29289  2020-11-18T06:33:48.749100
#
# [29290 rows x 6 columns]

# %%
train = spinlab_data[:int(len(spinlab_data)*0.7)]
test = spinlab_data[int(len(spinlab_data)*0.7):]

# %%
airq_data
# Out:
#                     date    sound       co2
# 0    2020-10-27 23:04:01  38.6815  466.4755
# 1    2020-10-27 23:08:02  38.5130  463.3480
# 2    2020-10-27 23:12:04  38.5720  464.1220
# 3    2020-10-27 23:16:05  38.4320  465.1120
# 4    2020-10-27 23:20:08  38.5365  465.8085
# ...                  ...      ...       ...
# 8193 2020-11-19 22:41:21  38.2840  518.4935
# 8194 2020-11-19 22:45:22  38.1280  517.8640
# 8195 2020-11-19 22:49:24  38.2845  514.4445
# 8196 2020-11-19 22:53:26  38.5625  516.1480
# 8197 2020-11-19 22:57:27  38.4205  513.2600
#
# [8198 rows x 3 columns]

# %% [markdown]
# ### 3.2.2. Calculate peripheral tables

# %%
import time

# %%
peripheral_a = pd.DataFrame()

start = time.time()
for index, row in spinlab_data.iterrows():
    t = pd.to_datetime(row['date'])
    until = t - pd.Timedelta(minutes=15)
    to_add = spinlab_data[(pd.to_datetime(spinlab_data['date']) >= until) & (pd.to_datetime(spinlab_data['date']) <= t)]
    to_add['join_key'] = int(row['index'])
    peripheral_a = peripheral_a.append(to_add)
end = time.time()
print("elapsed time: ", end - start)
    
peripheral_a
# Out:
# <ipython-input-91-92af83f893ab>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_add['join_key'] = int(row['index'])
#        index  temperature   humidity      light  occupancy  \
# 0          0    21.299999  49.200001   0.000000          0
# 0          0    21.299999  49.200001   0.000000          0
# 1          1    21.299999  49.700001  14.166667          0
# 0          0    21.299999  49.200001   0.000000          0
# 1          1    21.299999  49.700001  14.166667          0
# ...      ...          ...        ...        ...        ...
# 29285  29285    21.400000  46.500000   1.666667          0
# 29286  29286    21.400000  46.500000   1.666667          0
# 29287  29287    21.299999  46.500000   1.666667          0
# 29288  29288    21.400000  46.599998   1.666667          0
# 29289  29289    21.400000  46.500000   1.666667          0
#
#                              date  join_key
# 0      2020-10-28T17:17:02.752521         0
# 0      2020-10-28T17:17:02.752521         1
# 1      2020-10-28T17:18:32.387812         1
# 0      2020-10-28T17:17:02.752521         2
# 1      2020-10-28T17:18:32.387812         2
# ...                           ...       ...
# 29285  2020-11-18T06:29:43.843737     29289
# 29286  2020-11-18T06:30:44.438517     29289
# 29287  2020-11-18T06:31:45.033210     29289
# 29288  2020-11-18T06:32:45.628052     29289
# 29289  2020-11-18T06:33:48.749100     29289
#
# [439155 rows x 7 columns]

# %%
peripheral_b = pd.DataFrame()

start = time.time()
for index, row in spinlab_data.iterrows():
    t = pd.to_datetime(row['date'])
    until = t - pd.Timedelta(minutes=15)
    to_add = airq_data[(pd.to_datetime(airq_data['date']) >= until) & (pd.to_datetime(airq_data['date']) <= t)]
    to_add['join_key'] = int(row['index'])
    peripheral_b = peripheral_b.append(to_add)
end = time.time()
print("elapsed time: ", end - start)
    
peripheral_b
# Out:
# <ipython-input-96-93eaced2f4d7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   to_add['join_key'] = int(row['index'])
# elapsed time:  775.6587932109833
#                     date    sound       co2  join_key
# 268  2020-10-28 17:04:58  45.6950  600.7980         0
# 269  2020-10-28 17:08:59  42.9935  599.2870         0
# 270  2020-10-28 17:13:00  44.7085  594.9940         0
# 271  2020-10-28 17:17:02  41.9800  590.8455         0
# 268  2020-10-28 17:04:58  45.6950  600.7980         1
# ...                  ...      ...       ...       ...
# 7597 2020-11-18 06:26:16  38.0830  508.6010     29288
# 7598 2020-11-18 06:30:17  38.2075  506.0820     29288
# 7596 2020-11-18 06:22:14  38.1405  507.6770     29289
# 7597 2020-11-18 06:26:16  38.0830  508.6010     29289
# 7598 2020-11-18 06:30:17  38.2075  506.0820     29289
#
# [108799 rows x 4 columns]

# %%
peripheral_a = peripheral_a.drop(['index'], axis=1)
peripheral_a = peripheral_a.reset_index()
peripheral_a = peripheral_a.drop(['index'], axis=1)
peripheral_a = peripheral_a.reset_index()
peripheral_a
# Out:
#          index  temperature   humidity      light  occupancy  \
# 0            0    21.299999  49.200001   0.000000          0
# 1            1    21.299999  49.200001   0.000000          0
# 2            2    21.299999  49.700001  14.166667          0
# 3            3    21.299999  49.200001   0.000000          0
# 4            4    21.299999  49.700001  14.166667          0
# ...        ...          ...        ...        ...        ...
# 439150  439150    21.400000  46.500000   1.666667          0
# 439151  439151    21.400000  46.500000   1.666667          0
# 439152  439152    21.299999  46.500000   1.666667          0
# 439153  439153    21.400000  46.599998   1.666667          0
# 439154  439154    21.400000  46.500000   1.666667          0
#
#                               date  join_key
# 0       2020-10-28T17:17:02.752521         0
# 1       2020-10-28T17:17:02.752521         1
# 2       2020-10-28T17:18:32.387812         1
# 3       2020-10-28T17:17:02.752521         2
# 4       2020-10-28T17:18:32.387812         2
# ...                            ...       ...
# 439150  2020-11-18T06:29:43.843737     29289
# 439151  2020-11-18T06:30:44.438517     29289
# 439152  2020-11-18T06:31:45.033210     29289
# 439153  2020-11-18T06:32:45.628052     29289
# 439154  2020-11-18T06:33:48.749100     29289
#
# [439155 rows x 7 columns]

# %%
peripheral_b = peripheral_b.reset_index()
peripheral_b = peripheral_b.drop(['index'], axis=1)
peripheral_b = peripheral_b.reset_index()
peripheral_b
# Out:
#          index                date    sound       co2  join_key
# 0            0 2020-10-28 17:04:58  45.6950  600.7980         0
# 1            1 2020-10-28 17:08:59  42.9935  599.2870         0
# 2            2 2020-10-28 17:13:00  44.7085  594.9940         0
# 3            3 2020-10-28 17:17:02  41.9800  590.8455         0
# 4            4 2020-10-28 17:04:58  45.6950  600.7980         1
# ...        ...                 ...      ...       ...       ...
# 108794  108794 2020-11-18 06:26:16  38.0830  508.6010     29288
# 108795  108795 2020-11-18 06:30:17  38.2075  506.0820     29288
# 108796  108796 2020-11-18 06:22:14  38.1405  507.6770     29289
# 108797  108797 2020-11-18 06:26:16  38.0830  508.6010     29289
# 108798  108798 2020-11-18 06:30:17  38.2075  506.0820     29289
#
# [108799 rows x 5 columns]

# %% [markdown]
# ### 3.2.3 Create EntitiySet

# %%
peripheral_a.drop(["occupancy"], axis=1, inplace=True)

# %%
import featuretools as ft
es = ft.EntitySet(id="occupancy_spinlab_airq")

# %%
es = es.entity_from_dataframe(entity_id="population",
                              dataframe=spinlab_data,
                              time_index="date",
                              index="index")

es = es.entity_from_dataframe(entity_id="peripheral_spinlab",
                             dataframe=peripheral_a,
                             index='index')

es = es.entity_from_dataframe(entity_id="peripheral_airq",
                             dataframe=peripheral_b,
                             index="index")
es
# Out:
# Entityset: occupancy_spinlab_airq
#   Entities:
#     population [Rows: 29290, Columns: 7]
#     peripheral_spinlab [Rows: 439155, Columns: 6]
#     peripheral_airq [Rows: 108799, Columns: 5]
#   Relationships:
#     No relationships

# %%
relationships = []

parent = es["population"]["index"]
child = es["peripheral_airq"]["join_key"]
relationship = ft.Relationship(parent, child)
relationships.append(relationship)

parent = es["population"]["index"]
child = es["peripheral_spinlab"]["join_key"]
relationship = ft.Relationship(parent, child)
relationships.append(relationship)

es.add_relationships(relationships)
es
# Out:
# Entityset: occupancy_spinlab_airq
#   Entities:
#     population [Rows: 29290, Columns: 7]
#     peripheral_spinlab [Rows: 439155, Columns: 6]
#     peripheral_airq [Rows: 108799, Columns: 5]
#   Relationships:
#     peripheral_airq.join_key -> population.index
#     peripheral_spinlab.join_key -> population.index

# %%
memory_tracker.start()
start = time.time()
features, feature_names = ft.dfs(entityset=es, target_entity='population', 
                                 max_depth = 1)
end  = time.time()
print("Elapsed time: ")
print(end - start)
memory_tracker.stop()

print("Memory consumption: ")
print(memory_tracker.peak_consumption)


features
# Out:
# Elapsed time:
# 17.734830141067505
# Memory consumption:
# 0.057229312
#        temperature   humidity      light  occupancy  join_key  \
# index
# 0        21.299999  49.200001   0.000000          0         1
# 1        21.299999  49.700001  14.166667          0         1
# 2        21.299999  49.799999  14.166667          0         1
# 3        21.299999  49.799999  14.166667          0         1
# 4        21.299999  49.799999  14.166667          0         1
# ...            ...        ...        ...        ...       ...
# 29285    21.400000  46.500000   1.666667          0         1
# 29286    21.400000  46.500000   1.666667          0         1
# 29287    21.299999  46.500000   1.666667          0         1
# 29288    21.400000  46.599998   1.666667          0         1
# 29289    21.400000  46.500000   1.666667          0         1
#
#        COUNT(peripheral_airq)  MAX(peripheral_airq.co2)  \
# index
# 0                           4                   600.798
# 1                           4                   600.798
# 2                           4                   600.798
# 3                           3                   599.287
# 4                           4                   599.287
# ...                       ...                       ...
# 29285                       3                   508.601
# 29286                       4                   508.601
# 29287                       4                   508.601
# 29288                       4                   508.601
# 29289                       3                   508.601
#
#        MAX(peripheral_airq.sound)  MEAN(peripheral_airq.co2)  \
# index
# 0                         45.6950                 596.481125
# 1                         45.6950                 596.481125
# 2                         45.6950                 596.481125
# 3                         44.7085                 595.042167
# 4                         44.7085                 594.252875
# ...                           ...                        ...
# 29285                     38.1405                 507.812000
# 29286                     38.2075                 507.379500
# 29287                     38.2075                 507.379500
# 29288                     38.2075                 507.379500
# 29289                     38.2075                 507.453333
#
#        MEAN(peripheral_airq.sound)  ...  STD(peripheral_spinlab.humidity)  \
# index                               ...
# 0                        43.844250  ...                               NaN
# 1                        43.844250  ...                          0.353553
# 2                        43.844250  ...                          0.321454
# 3                        43.227333  ...                          0.287228
# 4                        42.812750  ...                          0.260767
# ...                            ...  ...                               ...
# 29285                    38.076500  ...                          0.048794
# 29286                    38.109250  ...                          0.050708
# 29287                    38.109250  ...                          0.051639
# 29288                    38.109250  ...                          0.051639
# 29289                    38.143667  ...                          0.051639
#
#        STD(peripheral_spinlab.light)  STD(peripheral_spinlab.temperature)  \
# index
# 0                                NaN                                  NaN
# 1                          10.017346                             0.000000
# 2                           8.179129                             0.000000
# 3                           7.083333                             0.000000
# 4                           6.335526                             0.000000
# ...                              ...                                  ...
# 29285                       0.000000                             0.035187
# 29286                       0.000000                             0.035187
# 29287                       0.000000                             0.041404
# 29288                       0.000000                             0.041404
# 29289                       0.000000                             0.041404
#
#        SUM(peripheral_spinlab.humidity)  SUM(peripheral_spinlab.light)  \
# index
# 0                             49.200001                       0.000000
# 1                             98.900002                      14.166667
# 2                            148.700001                      28.333333
# 3                            198.500000                      42.500000
# 4                            248.299999                      56.666667
# ...                                 ...                            ...
# 29285                        698.499985                      25.000000
# 29286                        698.399986                      25.000000
# 29287                        698.299988                      25.000000
# 29288                        698.299988                      25.000000
# 29289                        698.199989                      25.000000
#
#        SUM(peripheral_spinlab.temperature)  DAY(date)  MONTH(date)  \
# index
# 0                                21.299999         28           10
# 1                                42.599998         28           10
# 2                                63.899998         28           10
# 3                                85.199997         28           10
# 4                               106.499996         28           10
# ...                                    ...        ...          ...
# 29285                           320.799994         18           11
# 29286                           320.799994         18           11
# 29287                           320.699993         18           11
# 29288                           320.699993         18           11
# 29289                           320.699993         18           11
#
#        WEEKDAY(date)  YEAR(date)
# index
# 0                  2        2020
# 1                  2        2020
# 2                  2        2020
# 3                  2        2020
# 4                  2        2020
# ...              ...         ...
# 29285              2        2020
# 29286              2        2020
# 29287              2        2020
# 29288              2        2020
# 29289              2        2020
#
# [29290 rows x 41 columns]

# %%
features = ft.selection.remove_low_information_features(features)
features
# Out:
#        temperature   humidity      light  occupancy  COUNT(peripheral_airq)  \
# index
# 0        21.299999  49.200001   0.000000          0                       4
# 1        21.299999  49.700001  14.166667          0                       4
# 2        21.299999  49.799999  14.166667          0                       4
# 3        21.299999  49.799999  14.166667          0                       3
# 4        21.299999  49.799999  14.166667          0                       4
# ...            ...        ...        ...        ...                     ...
# 29285    21.400000  46.500000   1.666667          0                       3
# 29286    21.400000  46.500000   1.666667          0                       4
# 29287    21.299999  46.500000   1.666667          0                       4
# 29288    21.400000  46.599998   1.666667          0                       4
# 29289    21.400000  46.500000   1.666667          0                       3
#
#        MAX(peripheral_airq.co2)  MAX(peripheral_airq.sound)  \
# index
# 0                       600.798                     45.6950
# 1                       600.798                     45.6950
# 2                       600.798                     45.6950
# 3                       599.287                     44.7085
# 4                       599.287                     44.7085
# ...                         ...                         ...
# 29285                   508.601                     38.1405
# 29286                   508.601                     38.2075
# 29287                   508.601                     38.2075
# 29288                   508.601                     38.2075
# 29289                   508.601                     38.2075
#
#        MEAN(peripheral_airq.co2)  MEAN(peripheral_airq.sound)  \
# index
# 0                     596.481125                    43.844250
# 1                     596.481125                    43.844250
# 2                     596.481125                    43.844250
# 3                     595.042167                    43.227333
# 4                     594.252875                    42.812750
# ...                          ...                          ...
# 29285                 507.812000                    38.076500
# 29286                 507.379500                    38.109250
# 29287                 507.379500                    38.109250
# 29288                 507.379500                    38.109250
# 29289                 507.453333                    38.143667
#
#        MIN(peripheral_airq.co2)  ...  SKEW(peripheral_spinlab.temperature)  \
# index                            ...
# 0                      590.8455  ...                                   NaN
# 1                      590.8455  ...                                   NaN
# 2                      590.8455  ...                              0.000000
# 3                      590.8455  ...                              0.000000
# 4                      590.8455  ...                              0.000000
# ...                         ...  ...                                   ...
# 29285                  507.1580  ...                             -2.404763
# 29286                  506.0820  ...                             -2.404763
# 29287                  506.0820  ...                             -1.672082
# 29288                  506.0820  ...                             -1.672082
# 29289                  506.0820  ...                             -1.672082
#
#        STD(peripheral_spinlab.humidity)  STD(peripheral_spinlab.light)  \
# index
# 0                                   NaN                            NaN
# 1                              0.353553                      10.017346
# 2                              0.321454                       8.179129
# 3                              0.287228                       7.083333
# 4                              0.260767                       6.335526
# ...                                 ...                            ...
# 29285                          0.048794                       0.000000
# 29286                          0.050708                       0.000000
# 29287                          0.051639                       0.000000
# 29288                          0.051639                       0.000000
# 29289                          0.051639                       0.000000
#
#        STD(peripheral_spinlab.temperature)  SUM(peripheral_spinlab.humidity)  \
# index
# 0                                      NaN                         49.200001
# 1                                 0.000000                         98.900002
# 2                                 0.000000                        148.700001
# 3                                 0.000000                        198.500000
# 4                                 0.000000                        248.299999
# ...                                    ...                               ...
# 29285                             0.035187                        698.499985
# 29286                             0.035187                        698.399986
# 29287                             0.041404                        698.299988
# 29288                             0.041404                        698.299988
# 29289                             0.041404                        698.199989
#
#        SUM(peripheral_spinlab.light)  SUM(peripheral_spinlab.temperature)  \
# index
# 0                           0.000000                            21.299999
# 1                          14.166667                            42.599998
# 2                          28.333333                            63.899998
# 3                          42.500000                            85.199997
# 4                          56.666667                           106.499996
# ...                              ...                                  ...
# 29285                      25.000000                           320.799994
# 29286                      25.000000                           320.799994
# 29287                      25.000000                           320.699993
# 29288                      25.000000                           320.699993
# 29289                      25.000000                           320.699993
#
#        DAY(date)  MONTH(date)  WEEKDAY(date)
# index
# 0             28           10              2
# 1             28           10              2
# 2             28           10              2
# 3             28           10              2
# 4             28           10              2
# ...          ...          ...            ...
# 29285         18           11              2
# 29286         18           11              2
# 29287         18           11              2
# 29288         18           11              2
# 29289         18           11              2
#
# [29290 rows x 39 columns]

# %% [markdown]
# ### 3.2.3 Predictive Modelling & Evaluation

# %%
for col in features.columns:
    if features[col].nunique() == 1:
        print(col)
        features.drop([col], axis=1, inplace=True)

# %%
ft_train = features[:int(len(features)*0.7)]
ft_test = features[int(len(features)*0.7):]

# %%
ft_train_ = getml.data.DataFrame.from_pandas(ft_train, "featuretools_train")
ft_test_ = getml.data.DataFrame.from_pandas(ft_test, "featuretools_test")

# %%
ft_train
# Out:
#        temperature   humidity      light  occupancy  COUNT(peripheral_airq)  \
# index
# 0        21.299999  49.200001   0.000000          0                       4
# 1        21.299999  49.700001  14.166667          0                       4
# 2        21.299999  49.799999  14.166667          0                       4
# 3        21.299999  49.799999  14.166667          0                       3
# 4        21.299999  49.799999  14.166667          0                       4
# ...            ...        ...        ...        ...                     ...
# 20498    21.100000  43.700001   1.666667          0                       4
# 20499    21.100000  43.700001   1.666667          0                       3
# 20500    21.100000  43.700001   1.666667          0                       3
# 20501    21.000000  43.599998   1.666667          0                       4
# 20502    21.100000  43.700001   1.666667          0                       4
#
#        MAX(peripheral_airq.co2)  MAX(peripheral_airq.sound)  \
# index
# 0                       600.798                     45.6950
# 1                       600.798                     45.6950
# 2                       600.798                     45.6950
# 3                       599.287                     44.7085
# 4                       599.287                     44.7085
# ...                         ...                         ...
# 20498                   634.900                     42.4220
# 20499                   634.900                     42.4135
# 20500                   634.900                     42.4135
# 20501                   634.900                     42.4135
# 20502                   634.900                     42.4135
#
#        MEAN(peripheral_airq.co2)  MEAN(peripheral_airq.sound)  \
# index
# 0                     596.481125                    43.844250
# 1                     596.481125                    43.844250
# 2                     596.481125                    43.844250
# 3                     595.042167                    43.227333
# 4                     594.252875                    42.812750
# ...                          ...                          ...
# 20498                 632.515875                    42.382375
# 20499                 632.885333                    42.369167
# 20500                 632.885333                    42.369167
# 20501                 632.396875                    42.353250
# 20502                 632.396875                    42.353250
#
#        MIN(peripheral_airq.co2)  ...  SKEW(peripheral_spinlab.temperature)  \
# index                            ...
# 0                      590.8455  ...                                   NaN
# 1                      590.8455  ...                                   NaN
# 2                      590.8455  ...                              0.000000
# 3                      590.8455  ...                              0.000000
# 4                      590.8455  ...                              0.000000
# ...                         ...  ...                                   ...
# 20498                  631.2560  ...                              0.000000
# 20499                  631.2560  ...                              0.000000
# 20500                  631.2560  ...                              0.000000
# 20501                  630.9315  ...                             -3.872983
# 20502                  630.9315  ...                             -3.872983
#
#        STD(peripheral_spinlab.humidity)  STD(peripheral_spinlab.light)  \
# index
# 0                                   NaN                            NaN
# 1                              0.353553                      10.017346
# 2                              0.321454                       8.179129
# 3                              0.287228                       7.083333
# 4                              0.260767                       6.335526
# ...                                 ...                            ...
# 20498                          0.050710                       0.000000
# 20499                          0.048796                       0.000000
# 20500                          0.045775                       0.000000
# 20501                          0.045775                       0.000000
# 20502                          0.041405                       0.000000
#
#        STD(peripheral_spinlab.temperature)  SUM(peripheral_spinlab.humidity)  \
# index
# 0                                      NaN                         49.200001
# 1                                  0.00000                         98.900002
# 2                                  0.00000                        148.700001
# 3                                  0.00000                        198.500000
# 4                                  0.00000                        248.299999
# ...                                    ...                               ...
# 20498                              0.00000                        654.899998
# 20499                              0.00000                        655.000000
# 20500                              0.00000                        655.100002
# 20501                              0.02582                        655.100002
# 20502                              0.02582                        655.200005
#
#        SUM(peripheral_spinlab.light)  SUM(peripheral_spinlab.temperature)  \
# index
# 0                           0.000000                            21.299999
# 1                          14.166667                            42.599998
# 2                          28.333333                            63.899998
# 3                          42.500000                            85.199997
# 4                          56.666667                           106.499996
# ...                              ...                                  ...
# 20498                      25.000000                           316.500006
# 20499                      25.000000                           316.500006
# 20500                      25.000000                           316.500006
# 20501                      25.000000                           316.400005
# 20502                      25.000000                           316.400005
#
#        DAY(date)  MONTH(date)  WEEKDAY(date)
# index
# 0             28           10              2
# 1             28           10              2
# 2             28           10              2
# 3             28           10              2
# 4             28           10              2
# ...          ...          ...            ...
# 20498         12           11              3
# 20499         12           11              3
# 20500         12           11              3
# 20501         12           11              3
# 20502         12           11              3
#
# [20503 rows x 39 columns]

# %%
for df in [ft_train_, ft_test_]:
    df.set_role("occupancy", getml.data.roles.target)
    df.set_role(df.unused_float_names, getml.data.roles.numerical)

# %%
20/38
# Out:
# 0.5263157894736842

# %%
num_features = 20
predictor = getml.predictors.LogisticRegression()
selector = getml.predictors.LogisticRegression()
#seasonal = getml.preprocessors.Seasonal()
share = num_features/(len(features.columns)-1)

pipe_featuretools = getml.pipeline.Pipeline(
    tags=['featuretools'],
    predictors=[predictor],
    feature_selectors=selector,
    share_selected_features=share
    #preprocessors=[seasonal]
)

# %%
pipe_featuretools.fit(ft_train_)
# Out:
# Checking data model...
# OK.
#
# Trained pipeline.
# Time taken: 0h:0m:0.011707
# Pipeline(preprocessors=[], feature_learners=[],
#          feature_selectors=['LogisticRegression'], include_categorical=False,
#          peripheral=[], population='POPULATION',
#          predictors=['LogisticRegression'], tags=['featuretools'],
#          share_selected_features=0.5263157894736842)
#
# url: http://localhost:1709/getpipeline/pEVDid/0/

# %%
in_sample = pipe_featuretools.score(ft_train_)

out_of_sample = pipe_featuretools.score(ft_test_)

print("""
Accuracy (training): {:.5f}
AUC (training): {:.5f}\n
Accuracy (testing): {:.5f}
AUC (testing): {:.5f}
""".format(
    in_sample['accuracy'][0], 
    in_sample['auc'][0],
    out_of_sample['accuracy'][0], 
    out_of_sample['auc'][0])
)
# Out:
# Accuracy (training): 0.83246
# AUC (training): 0.84346
#
# Accuracy (testing): 0.85615
# AUC (testing): 0.85956

# %%
names, correlations = pipe_featuretools.features.correlations()

plt.subplots(figsize=(20, 10))

plt.bar(names, correlations, color='#6829c2')

plt.title("feature correlations")
plt.grid(True)
plt.xlabel("features")
plt.ylabel("correlations")
plt.xticks(rotation='vertical')

plt.show()

# %%
names, importances = pipe_featuretools.features.importances()

plt.subplots(figsize=(20, 10))

plt.bar(names, importances, color='#6829c2')

plt.title("feature importances")
plt.grid(True)
plt.xlabel("features")
plt.ylabel("importance")
plt.xticks(rotation='vertical')

plt.show()

# %%
len(names )
# Out:
# 14

# %% [markdown]
# ## 4. Without AirQ Data

# %%
spinlab_data['join_key'] = 1
train = spinlab_data[:int(len(spinlab_data)*0.7)]
test = spinlab_data[int(len(spinlab_data)*0.7):]

# %%
spinlab_data
# Out:
#        index  temperature   humidity      light  occupancy  \
# 0          0    21.299999  49.200001   0.000000          0
# 1          1    21.299999  49.700001  14.166667          0
# 2          2    21.299999  49.799999  14.166667          0
# 3          3    21.299999  49.799999  14.166667          0
# 4          4    21.299999  49.799999  14.166667          0
# ...      ...          ...        ...        ...        ...
# 29285  29285    21.400000  46.500000   1.666667          0
# 29286  29286    21.400000  46.500000   1.666667          0
# 29287  29287    21.299999  46.500000   1.666667          0
# 29288  29288    21.400000  46.599998   1.666667          0
# 29289  29289    21.400000  46.500000   1.666667          0
#
#                             date  join_key
# 0     2020-10-28 17:17:02.752521         1
# 1     2020-10-28 17:18:32.387812         1
# 2     2020-10-28 17:19:32.983309         1
# 3     2020-10-28 17:20:33.578042         1
# 4     2020-10-28 17:21:34.173782         1
# ...                          ...       ...
# 29285 2020-11-18 06:29:43.843737         1
# 29286 2020-11-18 06:30:44.438517         1
# 29287 2020-11-18 06:31:45.033210         1
# 29288 2020-11-18 06:32:45.628052         1
# 29289 2020-11-18 06:33:48.749100         1
#
# [29290 rows x 7 columns]

# %% [markdown]
# ### 4.1 Automated Feature Engineering with getML

# %%
data_full = getml.data.DataFrame.from_pandas(spinlab_data, "data_full")
data_train = getml.data.DataFrame.from_pandas(train, "data_train")
data_test = getml.data.DataFrame.from_pandas(test, "data_test")

# %%
for df in [data_full, data_train, data_test]:
    df.set_role("occupancy", getml.data.roles.target)
    df.set_role(['temperature', 'humidity', 'light'], getml.data.roles.numerical)
    df.set_role("date", getml.data.roles.time_stamp)
    df.set_role('join_key', getml.data.roles.join_key)

# %%
data_train
# Out:
# Name                           date   join_key   occupancy
# Role                     time_stamp   join_key      target
# Unit    time stamp, comparison only
# 0       2020-10-28T17:17:02.752521Z   1          0
# 1       2020-10-28T17:18:32.387812Z   1          0
# 2       2020-10-28T17:19:32.983309Z   1          0
# 3       2020-10-28T17:20:33.578042Z   1          0
# 4       2020-10-28T17:21:34.173782Z   1          0
#         ...                           ...        ...
# 20498   2020-11-12T02:34:11.292340Z   1          0
# 20499   2020-11-12T02:35:11.843801Z   1          0
# 20500   2020-11-12T02:36:12.411774Z   1          0
# 20501   2020-11-12T02:37:13.006317Z   1          0
# 20502   2020-11-12T02:38:13.601197Z   1          0
#
#
#
# Name    temperature    humidity       light
# Role      numerical   numerical   numerical
# Unit
# 0       21.3          49.2        0
# 1       21.3          49.7        14.1667
# 2       21.3          49.8        14.1667
# 3       21.3          49.8        14.1667
# 4       21.3          49.8        14.1667
#         ...           ...         ...
# 20498   21.1          43.7        1.66667
# 20499   21.1          43.7        1.66667
# 20500   21.1          43.7        1.66667
# 20501   21            43.6        1.66667
# 20502   21.1          43.7        1.66667
#
#
#
# Name           index
# Role    unused_float
# Unit
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
#         ...
# 20498   20498
# 20499   20499
# 20500   20500
# 20501   20501
# 20502   20502
#
# 20503 rows x 7 columns
# memory usage: 1.07 MB
# name: data_train
# type: getml.data.DataFrame
# url: http://localhost:1709/getdataframe/data_train/

# %%
population = getml.data.Placeholder('population')

peripheral = getml.data.Placeholder('peripheral')

# 1. The horizon is 0 hour (we do not predict the future). 
# 2. The memory is 30 minutes, so we allow the algorithm to 
#    use information from up to 30 minutes ago. 

population.join(
    peripheral,
    time_stamp='date',
    horizon=getml.data.time.hours(0),
    memory=getml.data.time.minutes(30)
)

population
# Out:
# placeholder   other placeholder   allow lagged targets   horizon
# population    peripheral          False                  0.0
#
#
#
# join keys used   memory   other join keys used   other time stamps used
#                  1800.0                          date
#
#
#
# join keys used   relationship   time stamps used   ...
#                  many-to-many   date               ...

# %%
multirel = getml.feature_learning.MultirelModel(
    num_features=10,
    loss_function=getml.feature_learning.loss_functions.CrossEntropyLoss,
)

relboost = getml.feature_learning.RelboostModel(
    num_features=10,
    loss_function=getml.feature_learning.loss_functions.CrossEntropyLoss,
)

predictor = getml.predictors.LogisticRegression()

# %%
pipe = getml.pipeline.Pipeline(
    tags=['memory: 30m', 'horizon: 0m', 'multirel', 'relboost'],
    population=population,
    peripheral=[peripheral],
    feature_learners=[multirel, relboost],
    predictors=[predictor]
)

# %%
pipe.check(data_train, [data_train])
# Out:
# Checking data model...
# OK.

# %%
pipe.fit(data_train, [data_train])
# Out:
# Checking data model...
# OK.
#
# Multirel: Training features...
# [========================================] 100%
#
# Relboost: Training features...
# [========================================] 100%
#
# Multirel: Building features...
# [========================================] 100%
#
# Relboost: Building features...
# [========================================] 100%
#
# LogisticRegression: Training as predictor...
# [========================================] 100%
#
# Trained pipeline.
# Time taken: 0h:1m:23.177714
# Pipeline(preprocessors=[], feature_learners=['MultirelModel', 'RelboostModel'],
#          feature_selectors=[], include_categorical=False,
#          peripheral=['peripheral'], population='population',
#          predictors=['LogisticRegression'],
#          tags=['memory: 30m', 'horizon: 0m', 'multirel', 'relboost'],
#          share_selected_features=0.5)
#
# url: http://localhost:1709/getpipeline/p1HqnM/0/

# %%
in_sample = pipe.score(data_train, [data_train])

out_of_sample = pipe.score(data_test, [data_test])

print("""
Accuracy (training): {:.5f}
AUC (training): {:.5f}\n
Accuracy (testing): {:.5f}
AUC (testing): {:.5f}
""".format(
    in_sample['accuracy'][0], 
    in_sample['auc'][0],
    out_of_sample['accuracy'][0], 
    out_of_sample['auc'][0])
)
# Out:
# Multirel: Building features...
# [========================================] 100%
#
# Relboost: Building features...
# [========================================] 100%
#
#
# Multirel: Building features...
# [========================================] 100%
#
# Relboost: Building features...
# [========================================] 100%
#
#
# Accuracy (training): 0.66951
# AUC (training): 0.19880
#
# Accuracy (testing): 0.73279
# AUC (testing): 0.19177

# %%
# Refers to the data from the last time
# we called .score(...).
fpr, tpr = pipe.metrics.roc_curve()

plt.subplots(figsize=(20, 10))

plt.plot(fpr, tpr, color='#6829c2')

plt.title("receiver operating characteristic (ROC)")
plt.grid(True)
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")

plt.show()

# %%
names, correlations = pipe.features.correlations()

plt.subplots(figsize=(20, 10))

plt.bar(names, correlations, color='#6829c2')
plt.title("feature correlations")
plt.grid(True)
plt.xlabel("features")
plt.ylabel("correlations")
plt.xticks(rotation='vertical')

plt.show()

# %%
names, importances = pipe.features.importances()

plt.subplots(figsize=(20, 10))

plt.bar(names, importances, color='#6829c2')

plt.title("feature importances")
plt.grid(True)
plt.xlabel("features")
plt.ylabel("importance")
plt.xticks(rotation='vertical')

plt.show()

# %%
pipe.features.to_sql()[names[0]]
# Out:
# ```sql
#
# ```

# %%
pipe.features.to_sql()[names[1]]
# Out:
# DROP TABLE IF EXISTS "FEATURE_1_8";
#
# CREATE TABLE "FEATURE_1_8" AS
# SELECT MIN( ( julianday( t1."date" ) - julianday( t2."date" ) ) * 86400.0 ) AS "feature_1_8",
#        t1.rowid AS "rownum"
# FROM "population" t1
# LEFT JOIN "peripheral" t2
# ON 1 = 1
# WHERE ( julianday( t2."date" ) <= julianday( t1."date" )
# AND ( julianday( t2."date", '+30.000000 minutes' ) > julianday( t1."date" ) OR julianday( t2."date", '+30.000000 minutes' ) IS NULL )
# ) AND (
#    ( ( t2."light" > 68.942577 OR t2."light" IS NULL  ) AND ( julianday( t1."date" ) > julianday( t2."date", '+16.648617 seconds' ) ) AND ( t2."light" > 82.452381 ) AND ( t2."temperature" <= 21.285714 ) )
# OR ( ( t2."light" > 68.942577 OR t2."light" IS NULL  ) AND ( julianday( t1."date" ) > julianday( t2."date", '+16.648617 seconds' ) ) AND ( t2."light" <= 82.452381 OR t2."light" IS NULL  ) AND ( t1."humidity" > 64.110868 ) )
# OR ( ( t2."light" > 68.942577 OR t2."light" IS NULL  ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+16.648617 seconds' ) ) AND ( t2."temperature" > 21.205263 OR t2."temperature" IS NULL  ) AND ( t2."humidity" <= 46.892307 ) )
# OR ( ( t2."light" > 68.942577 OR t2."light" IS NULL  ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+16.648617 seconds' ) ) AND ( t2."temperature" <= 21.205263 ) )
# OR ( ( t2."light" <= 68.942577 ) AND ( julianday( t1."date" ) > julianday( t2."date", '+28.402948 minutes' ) ) AND ( t1."light" <= 14.385965 ) AND ( t2."humidity" <= 64.417146 ) )
# OR ( ( t2."light" <= 68.942577 ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+28.402948 minutes' ) ) AND ( t2."light" > 32.368421 ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+20.133533 minutes' ) ) )
# OR ( ( t2."light" <= 68.942577 ) AND ( julianday( t1."date" ) <= julianday( t2."date", '+28.402948 minutes' ) ) AND ( t2."light" <= 32.368421 OR t2."light" IS NULL  ) AND ( t2."temperature" <= 19.511917 ) )
# )
# GROUP BY t1.rowid;

# %%
pipe.columns.to_pandas()
# Out:
#   population/peripheral       table         name  importance     target
# 0          [PERIPHERAL]  peripheral         date    0.019870  occupancy
# 1          [PERIPHERAL]  peripheral     humidity    0.029876  occupancy
# 2          [PERIPHERAL]  peripheral        light    0.703407  occupancy
# 3          [PERIPHERAL]  peripheral  temperature    0.019601  occupancy
# 4          [POPULATION]  population         date    0.019870  occupancy
# 5          [POPULATION]  population     humidity    0.010983  occupancy
# 6          [POPULATION]  population        light    0.158534  occupancy
# 7          [POPULATION]  population  temperature    0.037858  occupancy

# %%
names, importances = pipe.columns.importances()

names = [name.split('.')[1] for name in names]

plt.subplots(figsize=(20, 10))

plt.bar(names, importances, color='#6829c2')

plt.title("column importances")
plt.grid(True)
plt.xlabel("columns")
plt.ylabel("importance")
plt.xticks(rotation='horizontal')

plt.show()

# %% [markdown]
# ## 4.2 Automated Feature Engineering with featuretools

# %%
spinlab_data.drop(['join_key'], axis=1, inplace=True)

# %%
peripheral_a
# Out:
#          index  temperature   humidity      light                       date  \
# 0            0    21.299999  49.200001   0.000000 2020-10-28 17:17:02.752521
# 1            1    21.299999  49.200001   0.000000 2020-10-28 17:17:02.752521
# 2            2    21.299999  49.700001  14.166667 2020-10-28 17:18:32.387812
# 3            3    21.299999  49.200001   0.000000 2020-10-28 17:17:02.752521
# 4            4    21.299999  49.700001  14.166667 2020-10-28 17:18:32.387812
# ...        ...          ...        ...        ...                        ...
# 439150  439150    21.400000  46.500000   1.666667 2020-11-18 06:29:43.843737
# 439151  439151    21.400000  46.500000   1.666667 2020-11-18 06:30:44.438517
# 439152  439152    21.299999  46.500000   1.666667 2020-11-18 06:31:45.033210
# 439153  439153    21.400000  46.599998   1.666667 2020-11-18 06:32:45.628052
# 439154  439154    21.400000  46.500000   1.666667 2020-11-18 06:33:48.749100
#
#         join_key
# 0              0
# 1              1
# 2              1
# 3              2
# 4              2
# ...          ...
# 439150     29289
# 439151     29289
# 439152     29289
# 439153     29289
# 439154     29289
#
# [439155 rows x 6 columns]

# %%
es = ft.EntitySet(id="occupancy_spinlab")

# %%
es = es.entity_from_dataframe(entity_id="population",
                              dataframe=spinlab_data,
                              time_index="date",
                              index="index")

es = es.entity_from_dataframe(entity_id="peripheral_spinlab",
                             dataframe=peripheral_a,
                             index='index')

es
# Out:
# Entityset: occupancy_spinlab
#   Entities:
#     population [Rows: 29290, Columns: 6]
#     peripheral_spinlab [Rows: 439155, Columns: 6]
#   Relationships:
#     No relationships

# %%
relationships = []

parent = es["population"]["index"]
child = es["peripheral_spinlab"]["join_key"]
relationship = ft.Relationship(parent, child)

relationships.append(relationship)

es.add_relationships(relationships)
es
# Out:
# Entityset: occupancy_spinlab
#   Entities:
#     population [Rows: 29290, Columns: 6]
#     peripheral_spinlab [Rows: 439155, Columns: 6]
#   Relationships:
#     peripheral_spinlab.join_key -> population.index

# %%
memory_tracker.start()
start = time.time()
features, feature_names = ft.dfs(entityset=es, target_entity='population', 
                                 max_depth = 1)
end  = time.time()
print("Elapsed time: ")
print(end - start)
memory_tracker.stop()

print("Memory consumption: ")
print(memory_tracker.peak_consumption)


features
# Out:
# Elapsed time:
# 11.248172044754028
# Memory consumption:
# 0.01333248
#        temperature   humidity      light  occupancy  \
# index
# 0        21.299999  49.200001   0.000000          0
# 1        21.299999  49.700001  14.166667          0
# 2        21.299999  49.799999  14.166667          0
# 3        21.299999  49.799999  14.166667          0
# 4        21.299999  49.799999  14.166667          0
# ...            ...        ...        ...        ...
# 29285    21.400000  46.500000   1.666667          0
# 29286    21.400000  46.500000   1.666667          0
# 29287    21.299999  46.500000   1.666667          0
# 29288    21.400000  46.599998   1.666667          0
# 29289    21.400000  46.500000   1.666667          0
#
#        COUNT(peripheral_spinlab)  MAX(peripheral_spinlab.humidity)  \
# index
# 0                              1                         49.200001
# 1                              2                         49.700001
# 2                              3                         49.799999
# 3                              4                         49.799999
# 4                              5                         49.799999
# ...                          ...                               ...
# 29285                         15                         46.599998
# 29286                         15                         46.599998
# 29287                         15                         46.599998
# 29288                         15                         46.599998
# 29289                         15                         46.599998
#
#        MAX(peripheral_spinlab.light)  MAX(peripheral_spinlab.temperature)  \
# index
# 0                           0.000000                            21.299999
# 1                          14.166667                            21.299999
# 2                          14.166667                            21.299999
# 3                          14.166667                            21.299999
# 4                          14.166667                            21.299999
# ...                              ...                                  ...
# 29285                       1.666667                            21.400000
# 29286                       1.666667                            21.400000
# 29287                       1.666667                            21.400000
# 29288                       1.666667                            21.400000
# 29289                       1.666667                            21.400000
#
#        MEAN(peripheral_spinlab.humidity)  MEAN(peripheral_spinlab.light)  ...  \
# index                                                                     ...
# 0                              49.200001                        0.000000  ...
# 1                              49.450001                        7.083333  ...
# 2                              49.566667                        9.444444  ...
# 3                              49.625000                       10.625000  ...
# 4                              49.660000                       11.333333  ...
# ...                                  ...                             ...  ...
# 29285                          46.566666                        1.666667  ...
# 29286                          46.559999                        1.666667  ...
# 29287                          46.553333                        1.666667  ...
# 29288                          46.553333                        1.666667  ...
# 29289                          46.546666                        1.666667  ...
#
#        STD(peripheral_spinlab.humidity)  STD(peripheral_spinlab.light)  \
# index
# 0                                   NaN                            NaN
# 1                              0.353553                      10.017346
# 2                              0.321454                       8.179129
# 3                              0.287228                       7.083333
# 4                              0.260767                       6.335526
# ...                                 ...                            ...
# 29285                          0.048794                       0.000000
# 29286                          0.050708                       0.000000
# 29287                          0.051639                       0.000000
# 29288                          0.051639                       0.000000
# 29289                          0.051639                       0.000000
#
#        STD(peripheral_spinlab.temperature)  SUM(peripheral_spinlab.humidity)  \
# index
# 0                                      NaN                         49.200001
# 1                                 0.000000                         98.900002
# 2                                 0.000000                        148.700001
# 3                                 0.000000                        198.500000
# 4                                 0.000000                        248.299999
# ...                                    ...                               ...
# 29285                             0.035187                        698.499985
# 29286                             0.035187                        698.399986
# 29287                             0.041404                        698.299988
# 29288                             0.041404                        698.299988
# 29289                             0.041404                        698.199989
#
#        SUM(peripheral_spinlab.light)  SUM(peripheral_spinlab.temperature)  \
# index
# 0                           0.000000                            21.299999
# 1                          14.166667                            42.599998
# 2                          28.333333                            63.899998
# 3                          42.500000                            85.199997
# 4                          56.666667                           106.499996
# ...                              ...                                  ...
# 29285                      25.000000                           320.799994
# 29286                      25.000000                           320.799994
# 29287                      25.000000                           320.699993
# 29288                      25.000000                           320.699993
# 29289                      25.000000                           320.699993
#
#        DAY(date)  MONTH(date)  WEEKDAY(date)  YEAR(date)
# index
# 0             28           10              2        2020
# 1             28           10              2        2020
# 2             28           10              2        2020
# 3             28           10              2        2020
# 4             28           10              2        2020
# ...          ...          ...            ...         ...
# 29285         18           11              2        2020
# 29286         18           11              2        2020
# 29287         18           11              2        2020
# 29288         18           11              2        2020
# 29289         18           11              2        2020
#
# [29290 rows x 27 columns]

# %%
features = ft.selection.remove_low_information_features(features)
features
# Out:
#        temperature   humidity      light  occupancy  \
# index
# 0        21.299999  49.200001   0.000000          0
# 1        21.299999  49.700001  14.166667          0
# 2        21.299999  49.799999  14.166667          0
# 3        21.299999  49.799999  14.166667          0
# 4        21.299999  49.799999  14.166667          0
# ...            ...        ...        ...        ...
# 29285    21.400000  46.500000   1.666667          0
# 29286    21.400000  46.500000   1.666667          0
# 29287    21.299999  46.500000   1.666667          0
# 29288    21.400000  46.599998   1.666667          0
# 29289    21.400000  46.500000   1.666667          0
#
#        COUNT(peripheral_spinlab)  MAX(peripheral_spinlab.humidity)  \
# index
# 0                              1                         49.200001
# 1                              2                         49.700001
# 2                              3                         49.799999
# 3                              4                         49.799999
# 4                              5                         49.799999
# ...                          ...                               ...
# 29285                         15                         46.599998
# 29286                         15                         46.599998
# 29287                         15                         46.599998
# 29288                         15                         46.599998
# 29289                         15                         46.599998
#
#        MAX(peripheral_spinlab.light)  MAX(peripheral_spinlab.temperature)  \
# index
# 0                           0.000000                            21.299999
# 1                          14.166667                            21.299999
# 2                          14.166667                            21.299999
# 3                          14.166667                            21.299999
# 4                          14.166667                            21.299999
# ...                              ...                                  ...
# 29285                       1.666667                            21.400000
# 29286                       1.666667                            21.400000
# 29287                       1.666667                            21.400000
# 29288                       1.666667                            21.400000
# 29289                       1.666667                            21.400000
#
#        MEAN(peripheral_spinlab.humidity)  MEAN(peripheral_spinlab.light)  ...  \
# index                                                                     ...
# 0                              49.200001                        0.000000  ...
# 1                              49.450001                        7.083333  ...
# 2                              49.566667                        9.444444  ...
# 3                              49.625000                       10.625000  ...
# 4                              49.660000                       11.333333  ...
# ...                                  ...                             ...  ...
# 29285                          46.566666                        1.666667  ...
# 29286                          46.559999                        1.666667  ...
# 29287                          46.553333                        1.666667  ...
# 29288                          46.553333                        1.666667  ...
# 29289                          46.546666                        1.666667  ...
#
#        SKEW(peripheral_spinlab.temperature)  STD(peripheral_spinlab.humidity)  \
# index
# 0                                       NaN                               NaN
# 1                                       NaN                          0.353553
# 2                                  0.000000                          0.321454
# 3                                  0.000000                          0.287228
# 4                                  0.000000                          0.260767
# ...                                     ...                               ...
# 29285                             -2.404763                          0.048794
# 29286                             -2.404763                          0.050708
# 29287                             -1.672082                          0.051639
# 29288                             -1.672082                          0.051639
# 29289                             -1.672082                          0.051639
#
#        STD(peripheral_spinlab.light)  STD(peripheral_spinlab.temperature)  \
# index
# 0                                NaN                                  NaN
# 1                          10.017346                             0.000000
# 2                           8.179129                             0.000000
# 3                           7.083333                             0.000000
# 4                           6.335526                             0.000000
# ...                              ...                                  ...
# 29285                       0.000000                             0.035187
# 29286                       0.000000                             0.035187
# 29287                       0.000000                             0.041404
# 29288                       0.000000                             0.041404
# 29289                       0.000000                             0.041404
#
#        SUM(peripheral_spinlab.humidity)  SUM(peripheral_spinlab.light)  \
# index
# 0                             49.200001                       0.000000
# 1                             98.900002                      14.166667
# 2                            148.700001                      28.333333
# 3                            198.500000                      42.500000
# 4                            248.299999                      56.666667
# ...                                 ...                            ...
# 29285                        698.499985                      25.000000
# 29286                        698.399986                      25.000000
# 29287                        698.299988                      25.000000
# 29288                        698.299988                      25.000000
# 29289                        698.199989                      25.000000
#
#        SUM(peripheral_spinlab.temperature)  DAY(date)  MONTH(date)  \
# index
# 0                                21.299999         28           10
# 1                                42.599998         28           10
# 2                                63.899998         28           10
# 3                                85.199997         28           10
# 4                               106.499996         28           10
# ...                                    ...        ...          ...
# 29285                           320.799994         18           11
# 29286                           320.799994         18           11
# 29287                           320.699993         18           11
# 29288                           320.699993         18           11
# 29289                           320.699993         18           11
#
#        WEEKDAY(date)
# index
# 0                  2
# 1                  2
# 2                  2
# 3                  2
# 4                  2
# ...              ...
# 29285              2
# 29286              2
# 29287              2
# 29288              2
# 29289              2
#
# [29290 rows x 26 columns]

# %%
for col in features.columns:
    if features[col].nunique() == 1:
        print(col)
        features.drop([col], axis=1, inplace=True)

# %%
ft_train = features[:int(len(features)*0.7)]
ft_test = features[int(len(features)*0.7):]

# %%
ft_train_ = getml.data.DataFrame.from_pandas(ft_train, "featuretools_train")
ft_test_ = getml.data.DataFrame.from_pandas(ft_test, "featuretools_test")

# %%
for df in [ft_train_, ft_test_]:
    df.set_role("occupancy", getml.data.roles.target)
    df.set_role(df.unused_float_names, getml.data.roles.numerical)

# %%
num_features = 20
predictor = getml.predictors.LogisticRegression()
selector = getml.predictors.LogisticRegression()
#seasonal = getml.preprocessors.Seasonal()
share = num_features/(len(features.columns)-1)

pipe_featuretools = getml.pipeline.Pipeline(
    tags=['featuretools'],
    predictors=[predictor],
    feature_selectors=selector,
    share_selected_features=share
    #preprocessors=[seasonal]
)

# %%
pipe_featuretools.fit(ft_train_)
# Out:
# Checking data model...
# OK.
#
# LogisticRegression: Training as feature selector...
# [========================================] 100%
#
# LogisticRegression: Training as predictor...
# [========================================] 100%
#
# Trained pipeline.
# Time taken: 0h:0m:0.381879
# Pipeline(preprocessors=[], feature_learners=[],
#          feature_selectors=['LogisticRegression'], include_categorical=False,
#          peripheral=[], population='POPULATION',
#          predictors=['LogisticRegression'], tags=['featuretools'],
#          share_selected_features=0.8)
#
# url: http://localhost:1709/getpipeline/wciqyZ/0/

# %%
in_sample = pipe_featuretools.score(ft_train_)

out_of_sample = pipe_featuretools.score(ft_test_)

print("""
Accuracy (training): {:.5f}
AUC (training): {:.5f}\n
Accuracy (testing): {:.5f}
AUC (testing): {:.5f}
""".format(
    in_sample['accuracy'][0], 
    in_sample['auc'][0],
    out_of_sample['accuracy'][0], 
    out_of_sample['auc'][0])
)
# Out:
# Accuracy (training): 0.82910
# AUC (training): 0.85604
#
# Accuracy (testing): 0.84170
# AUC (testing): 0.84397
